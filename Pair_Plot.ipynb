# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
data = pd.read_csv("covid.csv")

# %%
data.head()
# Out:
#   Direction  Year      Date   Weekday Country Commodity Transport_Mode  \
# 0   Exports  2015  1/1/2015  Thursday     All       All            All
# 1   Exports  2015  2/1/2015    Friday     All       All            All
# 2   Exports  2015  3/1/2015  Saturday     All       All            All
# 3   Exports  2015  4/1/2015    Sunday     All       All            All
# 4   Exports  2015  5/1/2015    Monday     All       All            All
#
#   Measure      Value  Cumulative
# 0       $  104000000   104000000
# 1       $   96000000   200000000
# 2       $   61000000   262000000
# 3       $   74000000   336000000
# 4       $  105000000   442000000

# %%
sns.pairplot(data)
